# %%
from langchain.llms import HuggingFaceHub

# Set up the Hugging Face LLM
llm = HuggingFaceHub(
    repo_id="gpt2",  # Replace with the model you want
    model_kwargs={"temperature": 0.7, "max_length": 100},
    huggingfacehub_api_token="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"
)

# Use the LLM for a task
prompt = "What is the capital of France?"
response = llm(prompt)
print(response)
# Out:
# What is the capital of France?
#
# France is the capital of the world, and it's my duty to fulfill my role as chairman of the Western Council of the French Academy of Sciences to bring the Bill of Rights into line with the values and principles of the Declaration of Independence. At the same time I want to make sure that we are all committed to this project that is to be the biggest and best-organized organization in the world today. It's a very large task and I'll be working very hard to solve it.
#
# How much do you have to do to make sure that you have the right to organize this effort?
#
# I'm glad you asked and I am happy to answer. I'm very happy to be meeting with you. And I'm committed to staying here and working very hard. I know that you are happy to use that opportunity, because I want to talk to you about the Bill of Rights.
#
# How does Bill of Rights differ from the Declaration of Independence?
#
# ...

# %%
# !pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 33.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 kB 29.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.21
#     Uninstalling langchain-core-0.3.21:
#       Successfully uninstalled langchain-core-0.3.21
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.9
#     Uninstalling langchain-0.3.9:
#       Successfully uninstalled langchain-0.3.9
# ...

# %%
from langchain.document_loaders import TextLoader
from langchain.chains import RetrievalQA
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Load documents
loader = TextLoader("/content/New Text Document.txt")
documents = loader.load()

# Split the documents into smaller chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 500, # Adjust chunk size as needed
    chunk_overlap  = 50, # Adjust overlap as needed
)
split_documents = text_splitter.split_documents(documents)

# Create embeddings and vector store
embeddings = HuggingFaceEmbeddings()
vectorstore = FAISS.from_documents(split_documents, embeddings)

# Set up QA chain
qa_chain = RetrievalQA.from_chain_type(llm=llm, retriever=vectorstore.as_retriever())

# Ask a question
print(qa_chain.run("how many chapters in this content"))
# Out:
# <ipython-input-12-6ee425c052d3>:19: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embeddings = HuggingFaceEmbeddings()
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer.
#
# It includes virtual disks (VMDK, VDI formats), snapshots, linked clones, and shared folders for flexible storage management.	Virtual disks, snapshots, shared folders, and is optimized for seamless macOS integration.
#
# 1. Overview
# 1.1 Introduction
#
# List of Figures
# Figure 1:VMware EXSi	4
# Figure 2: VMware Workstation	5
# Figure 3: VMware Workstation	10
# Figure 4: Ubuntu 23.04 LTS	11
# Figure 5: ESXI server	18
# Figure 6: ESXI Host Client	18
# Figure 7: FreeNAS	19
#
# ...

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 31.4 MB/s eta 0:00:00
# ...

# %%
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationChain
from langchain.llms import HuggingFaceHub

# Set up the Hugging Face LLM
llm = HuggingFaceHub(
    repo_id="gpt2",  # Replace with the model you want
    model_kwargs={"temperature": 0.7, "max_length": 100},
    huggingfacehub_api_token="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"
)
# Set up memory and conversation chain
memory = ConversationBufferMemory()
conversation = ConversationChain(llm=llm, memory=memory)

# Interact with the chain
print(conversation.run("What is the capital of France?"))

# Reduce the input size for the next turn by summarizing or truncating the conversation history.
# For example, you could keep only the last few interactions or summarize the previous conversation.
# Here's an example of how to truncate the memory to keep the prompt size under the limit:
memory.chat_memory.messages = memory.chat_memory.messages[-2:]  # Keep only the last two messages

# Further reduce the input size by shortening the prompt
shortened_prompt = "History of the capital?"
print(conversation.run(shortened_prompt))
# Out:
# The following is a friendly conversation between a human and an AI. The AI is talkative and provides lots of specific details from its context. If the AI does not know the answer to a question, it truthfully says it does not know.
#
# Current conversation:
#
# Human: What is the capital of France?
# AI: Lyons.
#
# Human: What is the capital of China?
#
# AI: The capital of America.
#
# Human: Why are you studying philosophy at Berkeley?
#
# AI: Because I want to play guitar.
#
# Human: Why are you studying art at Stanford?
#
# AI: Because I want to study philosophy.
#
# Human: What is the capital of Japan?
#
# AI: The capital of Japan.
#
# Human: What is the capital of France?
#
# AI: The capital of France.
#
# Human: Why are you studying computer science at MIT?
#
# AI: Because I want to study computer science.
#
# Human: What is the capital of Denmark?
#
# AI: The capital of Denmark.
#
# Human: What are the capital of Finland?
#
# AI: The capital of Finland.
#
# ...

# %%
from transformers import pipeline
from langchain.llms import HuggingFacePipeline

# Load a local model using Transformers pipeline
local_pipeline = pipeline("text-generation", model="gpt2")

# Set up LangChain LLM with the pipeline
llm = HuggingFacePipeline(pipeline=local_pipeline)

# Use the LLM
prompt = "what is space station"
response = llm(prompt)
print(response)
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# what is space station? Do you have a space plane?"
#
# It's no easy task to identify what the space station is about; there are not too many details to make a definitive answer. "If someone takes two pictures of it in space

# %%
#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

# %%
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationChain
llm = HuggingFaceHub(
    repo_id="gpt2",  # Replace with your model
    model_kwargs={"temperature": 0.7, "max_length": 100, "max_new_tokens": 100},
    huggingfacehub_api_token="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"
)

# Set up memory and conversation chain
memory = ConversationBufferMemory()
conversation = ConversationChain(llm=llm, memory=memory)

# Interact with the chain
print(conversation.run("What is the capital of France?"))
print(conversation.run("Tell me more about its history."))
# Out:
# The following is a friendly conversation between a human and an AI. The AI is talkative and provides lots of specific details from its context. If the AI does not know the answer to a question, it truthfully says it does not know.
#
# Current conversation:
#
# Human: What is the capital of France?
# AI: French franc.
#
# Human: What is the capital of Russia?
#
# AI: Russian ruble.
#
# Human: What is the capital of France?
#
# AI: French franc.
#
# Human: What is the capital of Russia?
#
# AI: Russian ruble.
#
# Current conversation:
#
# Human: What is the capital of France?
#
# AI: French franc.
#
# Human: What is the capital of Russia?
#
# AI: Russian ruble
# The following is a friendly conversation between a human and an AI. The AI is talkative and provides lots of specific details from its context. If the AI does not know the answer to a question, it truthfully says it does not know.
#
# Current conversation:
# Human: What is the capital of France?
# ...

# %%
from langchain.document_loaders import TextLoader
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI

# Step 1: Load documents
loader = TextLoader("/content/New Text Document.txt")
documents = loader.load()

# Step 2: Create embeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Step 3: Store embeddings in a vector store
vectorstore = FAISS.from_documents(documents, embeddings)

# Step 4: Set up the QA system
llm = OpenAI(temperature=0.7, model_name="text-davinci-003")
qa_chain = RetrievalQA.from_chain_type(llm=llm, retriever=vectorstore.as_retriever())

# Step 5: Ask a question
query = "Summarize the main idea of the document."
answer = qa_chain.run(query)
print("Answer:", answer)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ...

# %%
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.schema import Document # Import Document class
from transformers import pipeline

# Step 1: Load Content
content = """
### Fascinating Historical Events That Changed the World

Throughout history, certain events have profoundly influenced the trajectory of human civilization. These moments not only shaped societies and cultures but also defined the course of progress, ideologies, and worldviews. Here, we delve into some of the most fascinating historical events that transformed the world, examining their causes, impacts, and legacies.

---

#### **1. The Fall of Constantinople (1453)**

The fall of Constantinople to the Ottoman Empire marked a turning point in world history. As the capital of the Byzantine Empire, Constantinople was a hub of commerce, culture, and Christianity for over a thousand years. On May 29, 1453, Sultan Mehmed II successfully breached the city’s formidable walls, ending the Byzantine Empire and establishing Ottoman dominance in the region.

**Impact:** The fall disrupted traditional trade routes between Europe and Asia, prompting explorers like Christopher Columbus to seek alternative pathways. This event indirectly led to the Age of Exploration, the discovery of the Americas, and the subsequent colonization of vast new territories. Additionally, many Greek scholars fled to Western Europe, bringing classical texts that helped spark the Renaissance.

---

#### **2. The Printing Revolution (1440s)**

Johannes Gutenberg’s invention of the movable-type printing press in the 1440s revolutionized the dissemination of knowledge. For the first time, books could be mass-produced, making them more affordable and accessible to a wider audience.

**Impact:** The printing press democratized information, leading to higher literacy rates and the spread of revolutionary ideas. It played a crucial role in the Protestant Reformation by enabling Martin Luther’s 95 Theses to reach a broad audience. Similarly, the Enlightenment’s intellectual advancements were accelerated by this technology, laying the foundation for modern democracy and scientific inquiry.

---

#### **3. The American Revolution (1775–1783)**

The American Revolution was a seminal event in which the Thirteen Colonies in North America declared independence from British rule. Fueled by Enlightenment ideals, the colonists sought freedom from taxation without representation and oppressive governance.

**Impact:** The success of the revolution inspired similar movements worldwide, including the French Revolution and Latin American independence struggles. The United States’ establishment as a democratic republic influenced political ideologies and governance structures globally, promoting ideals of liberty and self-determination.

---

#### **4. The Industrial Revolution (18th–19th Century)**

The Industrial Revolution began in Britain in the late 18th century and spread across the globe. Characterized by the transition from agrarian economies to industrialized ones, it introduced machinery, factories, and mass production techniques.

**Impact:** This era transformed every aspect of daily life. Innovations in transportation, such as the steam engine, facilitated global trade and migration. Urbanization increased as people moved to cities for factory jobs, while advancements in technology and infrastructure laid the groundwork for the modern economy. However, it also introduced challenges such as labor exploitation, environmental degradation, and income inequality.

---

#### **5. The French Revolution (1789–1799)**

The French Revolution was a period of radical social and political upheaval in France. Driven by economic hardship, social inequality, and Enlightenment philosophies, it led to the abolition of the monarchy and the rise of the French Republic.

**Impact:** The revolution’s ideals of liberty, equality, and fraternity resonated globally, inspiring other nations to pursue reform and revolution. It also led to the rise of Napoleon Bonaparte, whose conquests reshaped Europe’s political landscape. The French Revolution’s emphasis on human rights and democratic governance continues to influence political thought.

---

#### **6. World War I and the Treaty of Versailles (1914–1919)**

World War I, known as the "Great War," was a global conflict involving major world powers. It resulted in unprecedented devastation, with millions of lives lost and entire regions left in ruins. The Treaty of Versailles, which ended the war, imposed harsh penalties on Germany.

**Impact:** The war dismantled empires such as the Ottoman, Austro-Hungarian, and Russian empires, leading to the creation of new nations. However, the Treaty of Versailles’ punitive measures sowed resentment in Germany, contributing to the rise of Adolf Hitler and World War II. The war also marked a shift in global power dynamics, with the United States emerging as a significant force.

---

#### **7. The Discovery of Penicillin (1928)**

In 1928, Alexander Fleming discovered penicillin, the first antibiotic. This breakthrough revolutionized medicine, offering an effective treatment for bacterial infections that had previously been fatal.

**Impact:** Penicillin’s widespread use during World War II saved countless lives, and it became a cornerstone of modern medicine. The discovery ushered in the antibiotic age, drastically reducing mortality rates and enabling advancements in surgery and healthcare. However, the rise of antibiotic resistance in recent decades has emerged as a significant challenge.

---

#### **8. The Moon Landing (1969)**

On July 20, 1969, NASA’s Apollo 11 mission achieved a monumental milestone: humans landed on the Moon. Astronauts Neil Armstrong and Buzz Aldrin became the first people to walk on the lunar surface, while Michael Collins orbited above.

**Impact:** The Moon landing was a defining moment of the Space Race between the United States and the Soviet Union. It showcased humanity’s potential for scientific and technological achievement. The event inspired generations of scientists and engineers, fueling ongoing exploration of space and advancements in technology.

---

#### **9. The Fall of the Berlin Wall (1989)**

The Berlin Wall, a symbol of Cold War division, separated East and West Berlin for nearly three decades. On November 9, 1989, the wall fell, marking the end of Communist rule in Eastern Europe and the beginning of German reunification.

**Impact:** The fall of the Berlin Wall signaled the collapse of the Soviet Union and the triumph of democratic ideals over authoritarianism. It paved the way for the expansion of the European Union and NATO, reshaping geopolitics in the post-Cold War era. The event remains a powerful symbol of freedom and unity.

---

#### **10. The COVID-19 Pandemic (2020–?)**

The COVID-19 pandemic emerged as one of the most significant global crises in modern history. Originating in late 2019, the virus spread rapidly, leading to widespread illness, economic disruption, and societal change.

**Impact:** The pandemic accelerated technological adoption, particularly in remote work, education, and telemedicine. It underscored the importance of global health infrastructure and international cooperation. The crisis also highlighted socioeconomic disparities and the need for resilience in the face of future challenges. Its long-term effects are still unfolding, but it has already reshaped many aspects of daily life.

---

### Conclusion

These historical events, though distinct in nature and scope, share a common thread: their transformative impact on humanity. Each event, whether driven by innovation, conflict, or societal change, reshaped the world in profound ways. By studying these moments, we gain insights into the forces that have shaped our past and continue to influence our future. Such understanding not only deepens our appreciation of history but also equips us to navigate the challenges and opportunities that lie ahead..
"""

# Step 2: Preprocess Content
text_splitter = CharacterTextSplitter(chunk_size=600, chunk_overlap=500)
documents = text_splitter.split_text(content)

# Create Document objects instead of dictionaries
formatted_documents = [Document(page_content=doc) for doc in documents]


# Step 3: Create Embeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
vectorstore = FAISS.from_documents(formatted_documents, embeddings)
# Step 4: Load QA Model
qa_pipeline = pipeline("question-answering", model="distilbert-base-uncased-distilled-squad")

# Step 5: Answer Questions
def answer_question(question, retriever, qa_pipeline):
    # Retrieve relevant documents
    relevant_docs = retriever.get_relevant_documents(question)
    context = " ".join([doc.page_content for doc in relevant_docs])  # Combine retrieved chunks

    # Use QA pipeline to answer the question
    result = qa_pipeline(question=question, context=context)
    return result["answer"]

retriever = vectorstore.as_retriever()

# Example Questions
query1 = "in which period the rench revolution occur"
query2 = "what the content is explaining."

answer1 = answer_question(query1, retriever, qa_pipeline)
answer2 = answer_question(query2, retriever, qa_pipeline)

print("Question:", query1)
print("Answer:", answer1)

print("Question:", query2)
print("Answer:", answer2)
# Out:
# Question: in which period the rench revolution occur
# Answer: 1789–1799
# Question: what the content is explaining.
# Answer: freedom and unity

# %%
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Step 1: Load Content
content =  """
### Fascinating Historical Events That Changed the World

Throughout history, certain events have profoundly influenced the trajectory of human civilization. These moments not only shaped societies and cultures but also defined the course of progress, ideologies, and worldviews. Here, we delve into some of the most fascinating historical events that transformed the world, examining their causes, impacts, and legacies.

---

#### **1. The Fall of Constantinople (1453)**

The fall of Constantinople to the Ottoman Empire marked a turning point in world history. As the capital of the Byzantine Empire, Constantinople was a hub of commerce, culture, and Christianity for over a thousand years. On May 29, 1453, Sultan Mehmed II successfully breached the city’s formidable walls, ending the Byzantine Empire and establishing Ottoman dominance in the region.

**Impact:** The fall disrupted traditional trade routes between Europe and Asia, prompting explorers like Christopher Columbus to seek alternative pathways. This event indirectly led to the Age of Exploration, the discovery of the Americas, and the subsequent colonization of vast new territories. Additionally, many Greek scholars fled to Western Europe, bringing classical texts that helped spark the Renaissance.

---

#### **2. The Printing Revolution (1440s)**

Johannes Gutenberg’s invention of the movable-type printing press in the 1440s revolutionized the dissemination of knowledge. For the first time, books could be mass-produced, making them more affordable and accessible to a wider audience.

**Impact:** The printing press democratized information, leading to higher literacy rates and the spread of revolutionary ideas. It played a crucial role in the Protestant Reformation by enabling Martin Luther’s 95 Theses to reach a broad audience. Similarly, the Enlightenment’s intellectual advancements were accelerated by this technology, laying the foundation for modern democracy and scientific inquiry.

---

#### **3. The American Revolution (1775–1783)**

The American Revolution was a seminal event in which the Thirteen Colonies in North America declared independence from British rule. Fueled by Enlightenment ideals, the colonists sought freedom from taxation without representation and oppressive governance.

**Impact:** The success of the revolution inspired similar movements worldwide, including the French Revolution and Latin American independence struggles. The United States’ establishment as a democratic republic influenced political ideologies and governance structures globally, promoting ideals of liberty and self-determination.

---

#### **4. The Industrial Revolution (18th–19th Century)**

The Industrial Revolution began in Britain in the late 18th century and spread across the globe. Characterized by the transition from agrarian economies to industrialized ones, it introduced machinery, factories, and mass production techniques.

**Impact:** This era transformed every aspect of daily life. Innovations in transportation, such as the steam engine, facilitated global trade and migration. Urbanization increased as people moved to cities for factory jobs, while advancements in technology and infrastructure laid the groundwork for the modern economy. However, it also introduced challenges such as labor exploitation, environmental degradation, and income inequality.

---

#### **5. The French Revolution (1789–1799)**

The French Revolution was a period of radical social and political upheaval in France. Driven by economic hardship, social inequality, and Enlightenment philosophies, it led to the abolition of the monarchy and the rise of the French Republic.

**Impact:** The revolution’s ideals of liberty, equality, and fraternity resonated globally, inspiring other nations to pursue reform and revolution. It also led to the rise of Napoleon Bonaparte, whose conquests reshaped Europe’s political landscape. The French Revolution’s emphasis on human rights and democratic governance continues to influence political thought.

---

#### **6. World War I and the Treaty of Versailles (1914–1919)**

World War I, known as the "Great War," was a global conflict involving major world powers. It resulted in unprecedented devastation, with millions of lives lost and entire regions left in ruins. The Treaty of Versailles, which ended the war, imposed harsh penalties on Germany.

**Impact:** The war dismantled empires such as the Ottoman, Austro-Hungarian, and Russian empires, leading to the creation of new nations. However, the Treaty of Versailles’ punitive measures sowed resentment in Germany, contributing to the rise of Adolf Hitler and World War II. The war also marked a shift in global power dynamics, with the United States emerging as a significant force.

---

#### **7. The Discovery of Penicillin (1928)**

In 1928, Alexander Fleming discovered penicillin, the first antibiotic. This breakthrough revolutionized medicine, offering an effective treatment for bacterial infections that had previously been fatal.

**Impact:** Penicillin’s widespread use during World War II saved countless lives, and it became a cornerstone of modern medicine. The discovery ushered in the antibiotic age, drastically reducing mortality rates and enabling advancements in surgery and healthcare. However, the rise of antibiotic resistance in recent decades has emerged as a significant challenge.

---

#### **8. The Moon Landing (1969)**

On July 20, 1969, NASA’s Apollo 11 mission achieved a monumental milestone: humans landed on the Moon. Astronauts Neil Armstrong and Buzz Aldrin became the first people to walk on the lunar surface, while Michael Collins orbited above.

**Impact:** The Moon landing was a defining moment of the Space Race between the United States and the Soviet Union. It showcased humanity’s potential for scientific and technological achievement. The event inspired generations of scientists and engineers, fueling ongoing exploration of space and advancements in technology.

---

#### **9. The Fall of the Berlin Wall (1989)**

The Berlin Wall, a symbol of Cold War division, separated East and West Berlin for nearly three decades. On November 9, 1989, the wall fell, marking the end of Communist rule in Eastern Europe and the beginning of German reunification.

**Impact:** The fall of the Berlin Wall signaled the collapse of the Soviet Union and the triumph of democratic ideals over authoritarianism. It paved the way for the expansion of the European Union and NATO, reshaping geopolitics in the post-Cold War era. The event remains a powerful symbol of freedom and unity.

---

#### **10. The COVID-19 Pandemic (2020–?)**

The COVID-19 pandemic emerged as one of the most significant global crises in modern history. Originating in late 2019, the virus spread rapidly, leading to widespread illness, economic disruption, and societal change.

**Impact:** The pandemic accelerated technological adoption, particularly in remote work, education, and telemedicine. It underscored the importance of global health infrastructure and international cooperation. The crisis also highlighted socioeconomic disparities and the need for resilience in the face of future challenges. Its long-term effects are still unfolding, but it has already reshaped many aspects of daily life.

---

### Conclusion

These historical events, though distinct in nature and scope, share a common thread: their transformative impact on humanity. Each event, whether driven by innovation, conflict, or societal change, reshaped the world in profound ways. By studying these moments, we gain insights into the forces that have shaped our past and continue to influence our future. Such understanding not only deepens our appreciation of history but also equips us to navigate the challenges and opportunities that lie ahead..
"""

# Step 2: Split Content
def split_content(content, chunk_size=200):
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', content)
    chunks = []
    current_chunk = ""

    for sentence in sentences:
        if len(current_chunk) + len(sentence) < chunk_size:
            current_chunk += " " + sentence
        else:
            chunks.append(current_chunk)
            current_chunk = sentence
    if current_chunk:
        chunks.append(current_chunk)
    return chunks

chunks = split_content(content)

# Step 3: Vectorize Content using TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(chunks)

# Step 4: Retrieve Relevant Chunk
def retrieve_relevant_chunk(query, vectorizer, X):
    query_vec = vectorizer.transform([query])
    cosine_similarities = cosine_similarity(query_vec, X)
    most_similar_idx = cosine_similarities.argmax()
    return chunks[most_similar_idx]

# Step 5: Generate Answer
def generate_answer(query, vectorizer, X):
    relevant_chunk = retrieve_relevant_chunk(query, vectorizer, X)
    return relevant_chunk

# Test with a query
query = "tell me about moon landing"
answer = generate_answer(query, vectorizer, X)
print(f"Question: {query}")
print(f"Answer: {answer}")
# Out:
# Question: tell me about moon landing
# Answer: The Moon Landing (1969)**
#
# On July 20, 1969, NASA’s Apollo 11 mission achieved a monumental milestone: humans landed on the Moon.
